# %%
import face_recognition
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

KNOWN_FACES_DIR = "F:\\OPENCV\\data\\mini" 
UNKNOWN_FACES_DIR = 'F:\\OPENCV\\mix'
TOLERANCE = 0.6
FRAME_THICKNESS = 3
FONT_THICKNESS = 2
MODEL= "cnn"

# %%
from numpy import loadtxt
from numpy import asarray
known_faces = loadtxt('known_faces_data.csv', delimiter=',')
known_names = loadtxt('known_names_data.csv', dtype='str' ,delimiter=',')
known_names=list(known_names)
known_faces=list(known_faces)

# %%
from os import walk

new_faces=[]

new_faces_data=[]

for (dirpath, dirnames, filenames) in walk(KNOWN_FACES_DIR):
    new_faces=dirnames
    break
print(new_faces)

    
for new in new_faces :  
    
    if new not in known_names :
         
        new_faces_data.append(new)
         
            
            
print(new_faces_data)
print(len(known_faces))
# Out:
# ['ajay', 'ajinkya', 'ani', 'anne_hathaway', 'arnold_schwarzenegger', 'ben_afflek', 'dwayne_johnson', 'elton_john', 'jerry_seinfeld', 'kate_beckinsale', 'keanu_reeves', 'lauren_cohan', 'madonna', 'manek', 'mindy_kaling', 'nik', 'niranjan', 'sakash', 'simon_pegg', 'sofia_vergara', 'suyash', 'vedant', 'will_smith']
# ['manek', 'vedant']
# 245

# %%
print('Loading known faces...')
# known_faces = []
# known_names = []

for name in new_faces_data:
    print(name)

    # Next we load every file of faces of known person
    for filename in os.listdir(f'{KNOWN_FACES_DIR}/{name}'):
        
        print(filename)

        # Load an image
        image = face_recognition.load_image_file(f'{KNOWN_FACES_DIR}/{name}/{filename}')

        # Get 128-dimension face encoding
        # Always returns a list of found faces, for this purpose we take first face only (assuming one face per image as you can't be twice on one image)
        
        encoding = face_recognition.face_encodings(image)[0]
#         print(len(encoding))
#         print(encoding)
#         print(encoding.shape)



       
#         print(encoding[0].shape)
        # Append encodings and name
        known_faces.append(encoding)
        known_names.append(name)

# cv2.destroyAllWindows()
# Out:
# Loading known faces...

# %%
print(len(known_names))
print(len(known_faces))
# print((known_faces))
# Out:
# 29
# 29

# %%
from numpy import asarray
from numpy import savetxt

known_faces_data = asarray(known_faces)
known_names_data= asarray(known_names)

savetxt('known_faces_data.csv', known_faces_data, delimiter=',')
savetxt('known_names_data.csv', known_names_data, fmt='%s',delimiter=',')

# %% [markdown]
# ## For Full Training

# %%
import face_recognition
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

KNOWN_FACES_DIR = "F:\\OPENCV\\data\\mini" 
UNKNOWN_FACES_DIR = 'F:\\OPENCV\\mix'
TOLERANCE = 0.6
FRAME_THICKNESS = 3
FONT_THICKNESS = 2
MODEL= "cnn"


print('Loading known faces...')
known_faces = []
known_names = []
# Out:
# Loading known faces...

# %%
    

for name in os.listdir(KNOWN_FACES_DIR):

    print(name)
    
    i=0
    
    for filename in os.listdir(f'{KNOWN_FACES_DIR}/{name}'):

        print(filename)

        try :

            image = face_recognition.load_image_file(f'{KNOWN_FACES_DIR}/{name}/{filename}')

            encoding = face_recognition.face_encodings(image)[0]
#             print(encoding)

            known_faces.append(encoding)
            known_names.append(name)
            
      
    

        except IndexError :
            pass
        i=i+1
        
        if i==14 :
            break
        
        
#         break
#     break
# Out:
# ajay
# ajay.jpg
# IMG_20190803_015913.jpg
# IMG_20190811_201315.jpg
# IMG_20191124_112934_Bokeh.jpg
# IMG_20191124_112958.jpg
# ajinkya
# 1.jpg
# ajinkya_135.jpg
# ajinkya_170.jpg
# ajinkya_180.jpg
# ajinkya_190.jpg
# ajinkya_205.jpg
# ajinkya_215.jpg
# ajinkya_295.jpg
# ajinkya_65.jpg
# ajinkya_85.jpg
# ajinkya_90.jpg
# ajinkya_95.jpg
# IMG_20191124_083944.jpg
# IMG_20191124_090741.jpg
# ani
# a1.jpg
# a3.jpg
# as.jpg
# IMG_20190615_235730.jpg
# IMG_20190818_232256_Bokeh.jpg
# IMG_20191124_092326.jpg
# anne_hathaway
# 316px-Anne_Hathaway_@_2018.09.15_Human_Rights_Campaign_National_Dinner,_Washington,_DC_USA_06194_(43805104245)_(cropped).jpg
# 353px-Anne_Hathaway_2019_(cropped).jpg
# 393px-Denzel_Washington_og_Anne_Hathaway_IMG_6550b_Harry_Wad.jpg
# 398px-Anne_Hathaway_in_2017.png
# 417px-Anne_Hathaway_in_2016.jpg
# 428px-Anne_Hathaway_TIFF_2008.jpg
# 443px-Anne_Hathaway_2013.jpg
# 476px-Anne_Hathaway_(cropped)_(cropped).png
# 498px-Anne_Hathaway_for_AHC.png
# ...

# %%
print(len(known_names))
print(len(known_faces))
print(known_names)
# Out:
# 268
# 268
# ...

# %%
from numpy import asarray
from numpy import savetxt

known_faces_data = asarray(known_faces)
known_names_data= asarray(known_names)

savetxt('known_faces_data.csv', known_faces_data, delimiter=',')
savetxt('known_names_data.csv', known_names_data, fmt='%s',delimiter=',')

# %% [markdown]
# ## Run from Here

# %%
import face_recognition
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

KNOWN_FACES_DIR = "F:\\OPENCV\\data\\mini" 
UNKNOWN_FACES_DIR = 'F:\\OPENCV\\mix'
TOLERANCE = 0.6
FRAME_THICKNESS = 3
FONT_THICKNESS = 2
MODEL= "cnn"

# %%
from numpy import loadtxt
from numpy import asarray
known_faces = loadtxt('known_faces_data.csv', delimiter=',')
known_names = loadtxt('known_names_data.csv', dtype='str' ,delimiter=',')

# %%
# print(known_names)
# print(len(known_faces))
known_names=list(known_names)
known_faces=list(known_faces)
print(known_faces)
# Out:
# [array([-0.18042296, -0.0075304 , -0.00441658, -0.11635732, -0.04151886,
#         0.02987701,  0.06890832, -0.14240518,  0.20465724, -0.15884434,
#         0.27715895, -0.01882968, -0.21546964, -0.11674976,  0.00497709,
#         0.04896637, -0.07507796, -0.19914925, -0.06446034, -0.07412039,
#         0.04217181, -0.1166857 , -0.00117244,  0.06437036, -0.19583984,
#        -0.32950914, -0.10863508, -0.09291368,  0.01315115, -0.12010743,
#         0.03178376,  0.0389487 , -0.29245323, -0.06401511, -0.12790456,
#         0.08953302, -0.04379794, -0.03956902,  0.19023849,  0.01729166,
#        -0.13682273, -0.03360002,  0.01566061,  0.25645256,  0.15178405,
#        -0.01599506,  0.03333363, -0.0695132 ,  0.06091835, -0.29844868,
#         0.08017055,  0.11973342,  0.09081319,  0.04107154,  0.03674263,
#        -0.10384762,  0.00954353,  0.05738144, -0.15189351,  0.11734984,
#         0.03923704,  0.0293953 , -0.05266032, -0.02389133,  0.25534871,
# ...

# %% [markdown]
# ##  From direct camera access

# %%
cap = cv2.VideoCapture(0)

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

while 1:
    ret, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x-20,y-20),(x+w+40,y+h+40),(255,0,0),2)
        temp=img[y-20:y+h+20,x-20:x+w+40]
        image=cv2.resize(temp, (125, 125))

#         cv2.imshow('sd',image)

        locations = face_recognition.face_locations(image, model=MODEL)


        encodings = face_recognition.face_encodings(image, locations)


        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        print(f', found {len(encodings)} face(s)')
        for face_encoding, face_location in zip(encodings, locations):

            results = face_recognition.compare_faces(known_faces, face_encoding, TOLERANCE)


            match = None
            if True in results:  # If at least one is true, get a name of first of found labels
                match = known_names[results.index(True)]
                print(f' - {match} from {results}')

                # Each location contains positions in order: top, right, bottom, left
                top_left = (face_location[3], face_location[0])
                bottom_right = (face_location[1], face_location[2])

                # Get color by name using our fancy function
                color =[0,255,0]

                # Paint frame
                cv2.rectangle(image, top_left, bottom_right, color, FRAME_THICKNESS)

                # Now we need smaller, filled grame below for a name
                # This time we use bottom in both corners - to start from bottom and move 50 pixels down
                top_left = (face_location[3], face_location[2])
                bottom_right = (face_location[1], face_location[2] + 22)

                # Paint frame
                cv2.rectangle(image, top_left, bottom_right, color, cv2.FILLED)

                # Wite a name
                cv2.putText(image, match, (face_location[3]+15 , face_location[2]+15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (200, 200, 200), FONT_THICKNESS)


        cv2.imshow('img',img)



    k = cv2.waitKey(30) & 0xff
    if k == 27 :
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# , found 1 face(s)
# , found 1 face(s)
#  - suyash from [False, False, False, False, False, False, False, False, False, True, True, False, False]
# , found 1 face(s)
#  - suyash from [False, False, False, False, False, False, False, False, False, True, True, False, False]
# , found 1 face(s)
#  - suyash from [False, False, False, False, False, False, False, False, False, True, True, False, False]
# , found 1 face(s)
#  - suyash from [False, False, False, False, False, False, False, False, False, True, True, False, False]
# , found 1 face(s)
#  - suyash from [False, False, False, False, False, False, False, False, False, True, True, False, False]
# , found 1 face(s)
#  - suyash from [False, False, False, False, False, False, False, False, False, True, True, False, False]
# , found 1 face(s)
#  - suyash from [False, False, False, False, False, False, False, False, False, True, True, False, False]
# , found 1 face(s)
# ...

# %%
print('Processing unknown faces...')
import numpy as np

for filename in os.listdir(UNKNOWN_FACES_DIR):


    print(f'Filename {filename}', end='')
    
    image = face_recognition.load_image_file(f'{UNKNOWN_FACES_DIR}/{filename}')
    
#     img_read=cv2.imread(img)
    
#     print(type(img))

#     image =cv2.resize(img, (400, 400))
    
# #     print(type(compressed))
    
#     cv2.imshow('image',compressed)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    
#     img = face_recognition(compressed)
    
#     image=face_recognition.load
        
    locations = face_recognition.face_locations(image, model=MODEL)
    print(type(locations))
#     location=list[locations]
    print(locations[0][0])
    
#     temp=image[locations[1]:locations[1]+locations[3],locations[0]:locations[0]+locations[2]]
    
#     cv2.imshow('image',temp)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()    

    # Now since we know loctions, we can pass them to face_encodings as second argument
    # Without that it will search for faces once again slowing down whole process
    encodings = face_recognition.face_encodings(image, locations)

    # We passed our image through face_locations and face_encodings, so we can modify it
    # First we need to convert it from RGB to BGR as we are going to work with cv2
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    # But this time we assume that there might be more faces in an image - we can find faces of dirrerent people
    
    print(f', found {len(encodings)} face(s)')
    for face_encoding, face_location in zip(encodings, locations):

        # We use compare_faces (but might use face_distance as well)
        # Returns array of True/False values in order of passed known_faces
        results = face_recognition.compare_faces(known_faces, face_encoding, TOLERANCE)

        # Since order is being preserved, we check if any face was found then grab index
        # then label (name) of first matching known face withing a tolerance
        
        match = None
        if True in results:  # If at least one is true, get a name of first of found labels
            match = known_names[results.index(True)]
            print(f' - {match} from {results}')

            # Each location contains positions in order: top, right, bottom, left
            top_left = (face_location[3], face_location[0])
            bottom_right = (face_location[1], face_location[2])

            # Get color by name using our fancy function
            color = [0,255,0]
            image= cv2.resize(np.float32(image), (50, 50))
            # Paint frame
            cv2.rectangle(image, top_left, bottom_right, color, FRAME_THICKNESS)

            # Now we need smaller, filled grame below for a name
            # This time we use bottom in both corners - to start from bottom and move 50 pixels down
            top_left = (face_location[3], face_location[2])
            bottom_right = (face_location[1], face_location[2] + 22)

            # Paint frame
            cv2.rectangle(image, top_left, bottom_right, color, cv2.FILLED)

            # Wite a name
            cv2.putText(image, match, (face_location[3] + 10, face_location[2] + 15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (200, 200, 200), FONT_THICKNESS)

    # Show image
    cv2.imshow(filename, image)
    cv2.waitKey(0)
    cv2.destroyWindow(filename)
    break
# Out:
# Processing unknown faces...
# Filename 0.jpg<class 'list'>
# 16
# , found 1 face(s)
#  - suyash from [False, False, False, False, False, False, False, False, False, True, True, False, False]

# %%
print('Processing unknown faces...')

for filename in os.listdir(UNKNOWN_FACES_DIR):


    print(f'Filename {filename}', end='')
    image = face_recognition.load_image_file(f'{UNKNOWN_FACES_DIR}/{filename}')


    locations = face_recognition.face_locations(image, model=MODEL)


    encodings = face_recognition.face_encodings(image, locations)


    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    print(f', found {len(encodings)} face(s)')
    for face_encoding, face_location in zip(encodings, locations):

        results = face_recognition.compare_faces(known_faces, face_encoding, TOLERANCE)
        
        
        match = None
        if True in results:  # If at least one is true, get a name of first of found labels
            match = known_names[results.index(True)]
            print(f' - {match} from {results}')

            # Each location contains positions in order: top, right, bottom, left
            top_left = (face_location[3], face_location[0])
            bottom_right = (face_location[1], face_location[2])

            # Get color by name using our fancy function
            color =[0,255,0]

            # Paint frame
            cv2.rectangle(image, top_left, bottom_right, color, FRAME_THICKNESS)

            # Now we need smaller, filled grame below for a name
            # This time we use bottom in both corners - to start from bottom and move 50 pixels down
            top_left = (face_location[3], face_location[2])
            bottom_right = (face_location[1], face_location[2] + 22)

            # Paint frame
            cv2.rectangle(image, top_left, bottom_right, color, cv2.FILLED)

            # Wite a name
            cv2.putText(image, match, (face_location[3] + 10, face_location[2] + 15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (200, 200, 200), FONT_THICKNESS)

    # Show image
    cv2.imshow(filename, image)
    cv2.waitKey(0)
    cv2.destroyWindow(filename)
# Out:
# Processing unknown faces...
# Filename 0.jpg, found 1 face(s)
#  - suyash from [False, False, False, False, False, False, False, False, False, True, True, False, False]

# %%
from PIL import Image
import numpy as np

w, h = 512, 512
data = np.zeros((h, w, 3), dtype=np.uint8)
data[0:256, 0:256] = [255, 0, 0] # red patch in upper left
img = Image.fromarray(data, 'RGB')

img.show()
